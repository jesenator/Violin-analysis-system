# %%
%connect COM6 --baudrate=115200 --user='micro' --password='python' --wait=0
# Out:
# Connected on COM6

# %%
# current simplified robot controller - doubles tie fidelity
from utime import sleep_ms, ticks_ms, ticks_diff
from spike import PrimeHub, LightMatrix, Button, StatusLight, ForceSensor, MotionSensor, Speaker, ColorSensor, App, DistanceSensor, Motor, MotorPair
from spike.control import wait_for_seconds, wait_until, Timer
from math import *
import hub


hammer = hub.port.A.motor
hammer.preset(hammer.get()[0])
cycleLength = 3
totalPositions = 16 * 3
hitsPerPosition = 3
totalHits = totalPositions * hitsPerPosition

def getSeconds():
    seconds = round(ticks_diff(ticks_ms(), start_ms)/1000)
    return seconds


print("ready") 
while not hub.button.right.is_pressed():
    sleep_ms(10)

sleep_ms(2000)
# print("starting")
start_ms = ticks_ms()

for video in range(totalHits):
    while (getSeconds() % cycleLength) != 0:
        sleep_ms(10)
    print(getSeconds())
    sleep_ms(1000)
    print("starting action " + str(video + 1) + " ... ", end = "")
    hammer.run_for_degrees(360, speed=25)
    print("done")
# Out:
# ready
# 0"m":3,"p":["right", 90]}
# starting action 1 ... done
# 3
# starting action 2 ... done
# 6
# starting action 3 ... done
# 9
# starting action 4 ... done
# 12
# starting action 5 ... done
# 15
# starting action 6 ... done
# 18
# starting action 7 ... done
# 21
# starting action 8 ... done
# 24
# starting action 9 ... done
# 27
# starting action 10 ... done
# 30
# starting action 11 ... done
# 33
# starting action 12 ... done
# 36
# starting action 13 ... done
# 39
# starting action 14 ... done
# 42
# starting action 15 ... done
# 45
# starting action 16 ... done
# 48
# starting action 17 ... done
# 51
# starting action 18 ... done
# 54
# starting action 19 ... done
# 57
# starting action 20 ... done
# 60
# starting action 21 ... done
# 63
# starting action 22 ... done
# 66
# starting action 23 ... done
# 69
# starting action 24 ... done
# 72
# starting action 25 ... done
# 75
# starting action 26 ... done
# 78
# starting action 27 ... done
# 81
# starting action 28 ... done
# 84m":14,"p":1}
# starting action 29 ... done
# 87
# starting action 30 ... done
# 90
# starting action 31 ... done
# 93
# starting action 32 ... done
# 96
# starting action 33 ... done
# 99
# starting action 34 ... done
# 102
# starting action 35 ... done
# 105
# starting action 36 ... done
# 108
# starting action 37 ... done
# 111
# starting action 38 ... done
# 114
# starting action 39 ... done
# 117
# starting action 40 ... done
# 120
# starting action 41 ... done
# 123
# starting action 42 ... done
# 126
# starting action 43 ... done
# 129
# starting action 44 ... done
# 132
# starting action 45 ... done
# 135
# starting action 46 ... done
# 138
# starting action 47 ... done
# 141
# starting action 48 ... done
# 144
# starting action 49 ... done
# 147
# starting action 50 ... done
# 150
# starting action 51 ... done
# 153
# starting action 52 ... done
# 156
# starting action 53 ... done
# 159
# starting action 54 ... done
# 162
# starting action 55 ... done
# 165
# starting action 56 ... done
# 168
# starting action 57 ... done
# 171
# starting action 58 ... done
# 174
# starting action 59 ... done
# 177
# starting action 60 ... done
# 180
#
#
# *** Sending Ctrl-C

# %%
# current simplified robot controller - doubles tie fidelity
from utime import sleep_ms, ticks_ms, ticks_diff
from spike import PrimeHub, LightMatrix, Button, StatusLight, ForceSensor, MotionSensor, Speaker, ColorSensor, App, DistanceSensor, Motor, MotorPair
from spike.control import wait_for_seconds, wait_until, Timer
from math import *
import hub


hammer = hub.port.A.motor
hammer.preset(hammer.get()[0])
cycleLength = 3
totalPositions = 12
hitsPerPosition = 1
totalHits = totalPositions * hitsPerPosition

def getSeconds():
    seconds = round(ticks_diff(ticks_ms(), start_ms)/1000)
    return seconds


print("ready") 
while True:
    while not hub.button.right.is_pressed():
        sleep_ms(10)

    hammer.run_for_degrees(360, speed=25)
# Out:
# ready
# Comms Exception timeout waiting for first EOF reception
